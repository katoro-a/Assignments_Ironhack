# %%
import pandas as pd 
#pip install numpy 
import numpy as np

# %%
file1 = pd.read_excel('/Users/Bijou/Desktop/Ironhack_prework_activities/Week_1/Day_2/Intro_to_pandas/file1_pandas.xlsx')
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2 = pd.read_excel('/Users/Bijou/Desktop/Ironhack_prework_activities/Week_1/Day_2/Intro_to_pandas/file2_pandas.xlsx')
file2.columns  
#not in the same order as file 1!!!!
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
file3 = pd.read_excel('/Users/Bijou/Desktop/Ironhack_prework_activities/Week_1/Day_2/Intro_to_pandas/file3_pandas.xlsx')
file3.columns 
#state is spelled st in the above columns, not the same order
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
#Another way to check if the column names are the same  
#file1.columns==file2.columns  
#file2.columns==file3.columns

# %%
#lower all the column names 
lower_case= lambda x:x.lower()
file1.columns= list(map(lower_case, file1.columns)) 
file1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
file2.columns= list(map(lower_case, file2.columns)) 
file2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
file3.columns= list(map(lower_case, file3.columns)) 
file3.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
#make sure all the column names are the same  
#changing column names 
file1=file1.rename(columns={'st':'state'})
file2=file2.rename(columns={'st':'state'}) 
file1 
file2
# Out:
#     customer       state gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
#reorganize the column names before putting them all together

# %%
#file1= file1[[]]
file2= file2[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
file3= file3[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]

# %%
file2.columns==file1.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
file3.columns==file2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
#put the files together

# %%
file1.shape
# Out:
# (1071, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
data=pd.concat([file1,file2,file3],axis=0)
#0 below 
#1 next to

# %%
data.shape
# Out:
# (9137, 11)

# %%
#which columns are numerical/categorical 
data.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer lifetime value       object
# income                         int64
# monthly premium auto           int64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
data.select_dtypes('object') 
#customer lifetime value needs to be numerical
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value number of open complaints     policy type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %%
data.select_dtypes(np.number)
# Out:
#       income  monthly premium auto  total claim amount
# 0          0                  1000            2.704934
# 1          0                    94         1131.464935
# 2      48767                   108          566.472247
# 3          0                   106          529.881344
# 4      36357                    68           17.269323
# ...      ...                   ...                 ...
# 7065   71941                    73          198.234764
# 7066   21604                    79          379.200000
# 7067       0                    85          790.784983
# 7068   21941                    96          691.200000
# 7069       0                    77          369.600000
#
# [9137 rows x 3 columns]

# %%
data.describe(include = "all")
# Out:
#        customer       state gender education  customer lifetime value  \
# count      9137        9137   9015      9137              9130.000000
# unique     9056           8      5         6              8211.000000
# top     XZ34917  California      F  Bachelor              4605.036646
# freq          2        3032   4560      2719                 6.000000
# mean        NaN         NaN    NaN       NaN                      NaN
# std         NaN         NaN    NaN       NaN                      NaN
# min         NaN         NaN    NaN       NaN                      NaN
# 25%         NaN         NaN    NaN       NaN                      NaN
# 50%         NaN         NaN    NaN       NaN                      NaN
# 75%         NaN         NaN    NaN       NaN                      NaN
# max         NaN         NaN    NaN       NaN                      NaN
#
#               income  monthly premium auto  number of open complaints  \
# ...

# %%
#Delete the column education and the number of open complaints from the dataframe.

# %%
data=data.drop(['education','number of open complaints'],axis=1)

# %%
data.head()
# Out:
#   customer       state gender customer lifetime value  income  \
# 0  RB50392  Washington    NaN                     NaN       0
# 1  QZ44356     Arizona      F              697953.59%       0
# 2  AI49188      Nevada      F             1288743.17%   48767
# 3  WW63253  California      M              764586.18%       0
# 4  GA49547  Washington      M              536307.65%   36357
#
#    monthly premium auto     policy type  vehicle class  total claim amount
# 0                  1000   Personal Auto  Four-Door Car            2.704934
# 1                    94   Personal Auto  Four-Door Car         1131.464935
# 2                   108   Personal Auto   Two-Door Car          566.472247
# 3                   106  Corporate Auto            SUV          529.881344
# 4                    68   Personal Auto  Four-Door Car           17.269323

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
#list(map(lambda x:x*100,['customer lifetime value']))

# %%
#data['customer lifetime value']=data['customer lifetime value'].astype('float64') 
#ERROR cannot convert a string to a float 




data['customer lifetime value'] = data['customer lifetime value'].replace('[\%,]', '', regex=True).astype(float)

# %%
data.head()
# Out:
#   customer       state gender  customer lifetime value  income  \
# 0  RB50392  Washington    NaN                      NaN       0
# 1  QZ44356     Arizona      F                697953.59       0
# 2  AI49188      Nevada      F               1288743.17   48767
# 3  WW63253  California      M                764586.18       0
# 4  GA49547  Washington      M                536307.65   36357
#
#    monthly premium auto     policy type  vehicle class  total claim amount
# 0                  1000   Personal Auto  Four-Door Car            2.704934
# 1                    94   Personal Auto  Four-Door Car         1131.464935
# 2                   108   Personal Auto   Two-Door Car          566.472247
# 3                   106  Corporate Auto            SUV          529.881344
# 4                    68   Personal Auto  Four-Door Car           17.269323

# %%
remove_percent=lambda x:x*100
data['customer lifetime value']=list(map(remove_percent,data['customer lifetime value']))

# %%
data.head(3)
# Out:
#   customer       state gender  customer lifetime value  income  \
# 0  RB50392  Washington    NaN                      NaN       0
# 1  QZ44356     Arizona      F               69795359.0       0
# 2  AI49188      Nevada      F              128874317.0   48767
#
#    monthly premium auto    policy type  vehicle class  total claim amount
# 0                  1000  Personal Auto  Four-Door Car            2.704934
# 1                    94  Personal Auto  Four-Door Car         1131.464935
# 2                   108  Personal Auto   Two-Door Car          566.472247

# %%
#Check for duplicate rows in the data and remove if any.

# %%
print(data.shape)
data = data.drop_duplicates()
print(data.shape)
# Out:
# (9137, 9)
# (9134, 9)

# %%
#Filter out the data for customers who have an income of 0 or less.

# %%
income_filter=data[(data['income'] < 0)]
# Out:
# Empty DataFrame
# Columns: [customer, state, gender, customer lifetime value, income, monthly premium auto, policy type, vehicle class, total claim amount]
# Index: []
