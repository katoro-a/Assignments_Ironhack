# %%
import pandas as pd
import numpy as np

# %%
Show the dataframe shape.
Standardize header names.
Which columns are numerical?
Which columns are categorical?
Check and deal with NaN values.
Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
BONUS: Put all the previously mentioned data transformations into a function.
# Out:
#   File "<ipython-input-32-8691faaaf17d>", line 1
#     Show the dataframe shape.
#          ^
# SyntaxError: invalid syntax

# %%
data=pd.read_excel('/Users/Bijou/Desktop/Ironhack_prework_activities/Week_1/Day_2/Customer_analysis_2/marketing_customer_analysis_2.xlsx')

# %%
data.head(3)
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response Coverage  \
# 0           0  DK49336     Arizona              4809.216960       No    Basic
# 1           1  KX64629  California              2228.525238       No    Basic
# 2           2  LZ68649  Washington             14947.917300       No    Basic
#
#   Education Effective To Date EmploymentStatus Gender  ...  \
# 0   College        2011-02-18         Employed      M  ...
# 1   College        2011-01-18       Unemployed      F  ...
# 2  Bachelor        2011-02-10         Employed      M  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# ...

# %%
data.shape
# Out:
# (10910, 26)

# %%
data.columns=list(map(lambda x:x.lower(),data.columns))
data.columns
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'vehicle type'],
#       dtype='object')

# %%
data.dtypes
# Out:
# unnamed: 0                                int64
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                 float64
# months since policy inception             int64
# number of open complaints               float64
# number of policies                        int64
# policy type                              object
# policy                                   object
# ...

# %%
#categorical columns 
data.select_dtypes('object')
# Out:
#       customer       state response  coverage education employmentstatus  \
# 0      DK49336     Arizona       No     Basic   College         Employed
# 1      KX64629  California       No     Basic   College       Unemployed
# 2      LZ68649  Washington       No     Basic  Bachelor         Employed
# 3      XL78013      Oregon      Yes  Extended   College         Employed
# 4      QA50777      Oregon       No   Premium  Bachelor    Medical Leave
# ...        ...         ...      ...       ...       ...              ...
# 10905  FE99816      Nevada       No   Premium  Bachelor       Unemployed
# 10906  KX53892      Oregon       No     Basic   College         Employed
# 10907  TL39050     Arizona       No  Extended  Bachelor         Employed
# 10908  WA60547  California       No   Premium   College         Employed
# 10909  IV32877         NaN      NaN     Basic  Bachelor       Unemployed
#
#       gender location code marital status     policy type        policy  \
# ...

# %%
#numerical columns 
data._get_numeric_data()
# Out:
#        unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# ...

# %%
#Check and deal with the nan values

# %%
nulls_df = pd.DataFrame(round(data.isna().sum()/len(data),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                      unnamed: 0           0.00
# 1                        customer           0.00
# 2                           state           5.78
# 3         customer lifetime value           0.00
# 4                        response           5.78
# 5                        coverage           0.00
# 6                       education           0.00
# 7               effective to date           0.00
# 8                employmentstatus           0.00
# 9                          gender           0.00
# 10                         income           0.00
# 11                  location code           0.00
# 12                 marital status           0.00
# 13           monthly premium auto           0.00
# 14        months since last claim           5.80
# 15  months since policy inception           0.00
# 16      number of open complaints           5.80
# 17             number of policies           0.00
# ...

# %%
columns_drop = nulls_df[nulls_df['percent_nulls']>0]['header_name']  # dummy case with 3 
print(columns_drop.values)
# Out:
# ['state' 'response' 'months since last claim' 'number of open complaints'
#  'vehicle class' 'vehicle size' 'vehicle type']

# %%
#find the mean of the vehicle type column , 50% nan maybe drop instead

#False 
data=data[data['state'].isna() == False]   
data=data[data['response'].isna() == False]   
data=data[data['months since last claim'].isna() == False]   
data=data[data['number of open complaints'].isna() == False]  
data=data[data['vehicle class'].isna() == False]   
data=data[data['vehicle size'].isna() == False]

# %%
#remove vehicle type more than 50% null 

data=data.drop(['vehicle type'],axis=1)

# %%
data
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective to date employmentstatus  \
# ...

# %%
Datetime format - 
Extract the months from the dataset and store in a separate column.

# %%
data.dtypes
# Out:
# unnamed: 0                                int64
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                 float64
# months since policy inception             int64
# number of open complaints               float64
# number of policies                        int64
# policy type                              object
# policy                                   object
# ...

# %%
month = lambda x:x.strftime(format='%B')
data['month']= list(map(month,data['effective to date']))

# %%
data.head()
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 6           6  IW72280  California              5035.035257       No
#
#    coverage education effective to date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 6     Basic    Doctor        2011-02-14         Employed      F  ...
#
#    number of open complaints number of policies     policy type        policy  \
# ...

# %%
Then filter the data to show only the information for the first quarter , 
ie. January, February and March. Hint: If data from March does not exist, 
consider only January and February.

# %%
data['month'].unique()
# Out:
# array(['February', 'January'], dtype=object)

# %%
data[(data['month'] == 'January') & (data['month'] == 'Febuary')]
data.head(5)
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 6           6  IW72280  California              5035.035257       No
#
#    coverage education effective to date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 6     Basic    Doctor        2011-02-14         Employed      F  ...
#
#    number of open complaints number of policies     policy type        policy  \
# ...
